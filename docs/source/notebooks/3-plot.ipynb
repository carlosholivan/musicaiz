# %% [markdown]
# # Plotting

# %%
import sys
sys.path.insert(1, "../")
from musicaiz import loaders, plotters

# %%
file = "H:\\INVESTIGACION\\Datasets\\JSB Chorales\\train\\2.mid"
midi = loaders.Musa(
    file,
    subdivision_note="sixteenth",
)

# %%
plot = plotters.Pianoroll(midi)
plot.plot_instruments(
    program=0,
    bar_start=0,
    bar_end=midi.total_bars,
    show=True
)
